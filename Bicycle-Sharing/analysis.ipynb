# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
df_train=pd.read_csv('/home/kongweikun/PycharmProjects/kaggle/Bicycle-Sharing/resourses/train.csv')
df_train.head()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>datetime</th>
#       <th>season</th>
#       <th>holiday</th>
#       <th>workingday</th>
#       <th>weather</th>
#       <th>temp</th>
#       <th>atemp</th>
#       <th>humidity</th>
#       <th>windspeed</th>
#       <th>casual</th>
#       <th>registered</th>
#       <th>count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2011-01-01 00:00:00</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>9.84</td>
#       <td>14.395</td>
#       <td>81</td>
#       <td>0.0</td>
#       <td>3</td>
#       <td>13</td>
#       <td>16</td>
#     </tr>
# ...
